# %% [markdown]
# https://towardsdatascience.com/an-introduction-to-bayesian-inference-in-pystan-c27078e58d53

# %% [markdown]
# build a model

# %%
import pystan
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
sns.set()  # Nice plot aesthetic
np.random.seed(101)

# %%
model = """
data {
    int<lower=0> N;
    vector[N] x;
    vector[N] y;
}
parameters {
    real alpha;
    real beta;
    real<lower=0> sigma;
}
model {
    y ~ normal(alpha + beta * x, sigma);
}
"""

# %% [markdown]
# Data generation

# %%
# Parameters to be inferred
alpha = 4.0
beta = 0.5
sigma = 1.0

# Generate and plot data
x = 10 * np.random.rand(100)
y = alpha + beta * x
y = np.random.normal(y, scale=sigma)

# %%
# Put our data in a dictionary
data = {'N': len(x), 'x': x, 'y': y}

# Compile the model
sm = pystan.StanModel(model_code=model)

# Train the model and generate samples
fit = sm.sampling(data=data, iter=1000, chains=4, warmup=500, thin=1, seed=101)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_cb4cc9c2a04d0e34d711077557307fb7 NOW.
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1280:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:52:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_cholesky_factor_corr.hpp:5:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_cholesky_factor.hpp:6:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/err/is_lower_triangular.hpp:25:27: warning: 'ptr_fun<double, double>' is deprecated [-Wdeprecated-declarations]
#   return y.unaryExpr(std::ptr_fun(internal::notNan))
#                           ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__functional/pointer_to_unary_function.h:37:1: note: 'ptr_fun<double, double>' has been explicitly marked deprecated here
# _LIBCPP_DEPRECATED_IN_CXX11 inline _LIBCPP_INLINE_VISIBILITY
# ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__config:850:41: note: expanded from macro '_LIBCPP_DEPRECATED_IN_CXX11'
# #    define _LIBCPP_DEPRECATED_IN_CXX11 _LIBCPP_DEPRECATED
#                                         ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__config:835:49: note: expanded from macro '_LIBCPP_DEPRECATED'
# #      define _LIBCPP_DEPRECATED __attribute__((deprecated))
#                                                 ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:68:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/Phi.hpp:5:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/scal/fun/Phi.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/scal/fun/constants.hpp:4:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/math/constants/constants.hpp:13:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/math/tools/convert_from_string.hpp:15:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast.hpp:32:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/try_lexical_convert.hpp:44:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/detail/converter_lexical.hpp:54:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/detail/converter_lexical_streams.hpp:285:21: warning: 'sprintf' is deprecated: This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead. [-Wdeprecated-declarations]
#                     sprintf(begin,
#                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/stdio.h:180:1: note: 'sprintf' has been explicitly marked deprecated here
# __deprecated_msg("This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead.")
# ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/sys/cdefs.h:215:48: note: expanded from macro '__deprecated_msg'
#         #define __deprecated_msg(_msg) __attribute__((__deprecated__(_msg)))
#                                                       ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:68:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/Phi.hpp:5:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/scal/fun/Phi.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/scal/fun/constants.hpp:4:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/math/constants/constants.hpp:13:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/math/tools/convert_from_string.hpp:15:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast.hpp:32:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/try_lexical_convert.hpp:44:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/detail/converter_lexical.hpp:54:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/detail/converter_lexical_streams.hpp:297:21: warning: 'sprintf' is deprecated: This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead. [-Wdeprecated-declarations]
#                     sprintf(begin,
#                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/stdio.h:180:1: note: 'sprintf' has been explicitly marked deprecated here
# __deprecated_msg("This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead.")
# ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/sys/cdefs.h:215:48: note: expanded from macro '__deprecated_msg'
#         #define __deprecated_msg(_msg) __attribute__((__deprecated__(_msg)))
#                                                       ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:68:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/Phi.hpp:5:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/scal/fun/Phi.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/scal/fun/constants.hpp:4:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/math/constants/constants.hpp:13:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/math/tools/convert_from_string.hpp:15:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast.hpp:32:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/try_lexical_convert.hpp:44:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/detail/converter_lexical.hpp:54:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/lexical_cast/detail/converter_lexical_streams.hpp:310:21: warning: 'sprintf' is deprecated: This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead. [-Wdeprecated-declarations]
#                     sprintf(begin,
#                     ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/stdio.h:180:1: note: 'sprintf' has been explicitly marked deprecated here
# __deprecated_msg("This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead.")
# ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/sys/cdefs.h:215:48: note: expanded from macro '__deprecated_msg'
#         #define __deprecated_msg(_msg) __attribute__((__deprecated__(_msg)))
#                                                       ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:109:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Sparse:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/SparseCore:61:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/SparseCore/TriangularSolver.h:273:13: warning: variable 'count' set but not used [-Wunused-but-set-variable]
#       Index count = 0;
#             ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:109:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/fun/csr_extract_u.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Sparse:31:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/SparseLU:33:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/SparseLU/SparseLU_heap_relax_snode.h:78:9: warning: variable 'nsuper_et_post' set but not used [-Wunused-but-set-variable]
#   Index nsuper_et_post = 0; // Number of relaxed snodes in postordered etree
#         ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/SparseLU/SparseLU_heap_relax_snode.h:79:9: warning: variable 'nsuper_et' set but not used [-Wunused-but-set-variable]
#   Index nsuper_et = 0; // Number of relaxed snodes in the original etree
#         ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array_wrapper.hpp:22:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/collection_size_type.hpp:10:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:28:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_assign.hpp:65:7: warning: builtin __has_nothrow_assign is deprecated; use __is_nothrow_assignable instead [-Wdeprecated-builtins]
#       BOOST_HAS_NOTHROW_ASSIGN(T)
#       ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:205:43: note: expanded from macro 'BOOST_HAS_NOTHROW_ASSIGN'
# #     define BOOST_HAS_NOTHROW_ASSIGN(T) (__has_nothrow_assign(T) && !is_volatile<T>::value && is_assignable<T&, const T&>::value)
#                                           ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array_wrapper.hpp:22:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/collection_size_type.hpp:10:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:29:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_constructor.hpp:27:84: warning: builtin __has_nothrow_constructor is deprecated; use __is_nothrow_constructible instead [-Wdeprecated-builtins]
# template <class T> struct has_nothrow_constructor : public integral_constant<bool, BOOST_HAS_NOTHROW_CONSTRUCTOR(T)>{};
#                                                                                    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:199:48: note: expanded from macro 'BOOST_HAS_NOTHROW_CONSTRUCTOR'
# #     define BOOST_HAS_NOTHROW_CONSTRUCTOR(T) (__has_nothrow_constructor(T) && is_default_constructible<T>::value)
#                                                ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array_wrapper.hpp:22:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/collection_size_type.hpp:10:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:30:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_copy.hpp:36:89: warning: builtin __has_nothrow_copy is deprecated; use __is_nothrow_constructible instead [-Wdeprecated-builtins]
# template <class T> struct has_nothrow_copy_constructor : public integral_constant<bool, BOOST_HAS_NOTHROW_COPY(T)>{};
#                                                                                         ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:202:41: note: expanded from macro 'BOOST_HAS_NOTHROW_COPY'
# #     define BOOST_HAS_NOTHROW_COPY(T) (__has_nothrow_copy(T) && !is_volatile<T>::value && !is_reference<T>::value && is_copy_constructible<T>::value)
#                                         ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array_wrapper.hpp:22:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/collection_size_type.hpp:10:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:30:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_copy.hpp:36:89: warning: builtin __has_nothrow_copy is deprecated; use __is_nothrow_constructible instead [-Wdeprecated-builtins]
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:202:41: note: expanded from macro 'BOOST_HAS_NOTHROW_COPY'
# #     define BOOST_HAS_NOTHROW_COPY(T) (__has_nothrow_copy(T) && !is_volatile<T>::value && !is_reference<T>::value && is_copy_constructible<T>::value)
#                                         ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/serialization.hpp:61:1: note: in instantiation of template class 'boost::has_nothrow_copy_constructor<unsigned int>' requested here
# BOOST_STRONG_TYPEDEF(unsigned int, version_type)
# ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:39:54: note: expanded from macro 'BOOST_STRONG_TYPEDEF'
#     explicit D(const T& t_) BOOST_NOEXCEPT_IF(boost::has_nothrow_copy_constructor<T>::value) : t(t_) {}          \
#                                                      ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array_wrapper.hpp:22:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/collection_size_type.hpp:10:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:29:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_constructor.hpp:27:84: warning: builtin __has_nothrow_constructor is deprecated; use __is_nothrow_constructible instead [-Wdeprecated-builtins]
# template <class T> struct has_nothrow_constructor : public integral_constant<bool, BOOST_HAS_NOTHROW_CONSTRUCTOR(T)>{};
#                                                                                    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:199:48: note: expanded from macro 'BOOST_HAS_NOTHROW_CONSTRUCTOR'
# #     define BOOST_HAS_NOTHROW_CONSTRUCTOR(T) (__has_nothrow_constructor(T) && is_default_constructible<T>::value)
#                                                ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_constructor.hpp:69:68: note: in instantiation of template class 'boost::has_nothrow_constructor<unsigned int>' requested here
# template <class T> struct has_nothrow_default_constructor : public has_nothrow_constructor<T>{};
#                                                                    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/serialization.hpp:61:1: note: in instantiation of template class 'boost::has_nothrow_default_constructor<unsigned int>' requested here
# BOOST_STRONG_TYPEDEF(unsigned int, version_type)
# ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:40:34: note: expanded from macro 'BOOST_STRONG_TYPEDEF'
#     D() BOOST_NOEXCEPT_IF(boost::has_nothrow_default_constructor<T>::value) : t() {}                             \
#                                  ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/array_wrapper.hpp:22:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/collection_size_type.hpp:10:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:28:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_assign.hpp:65:7: warning: builtin __has_nothrow_assign is deprecated; use __is_nothrow_assignable instead [-Wdeprecated-builtins]
#       BOOST_HAS_NOTHROW_ASSIGN(T)
#       ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:205:43: note: expanded from macro 'BOOST_HAS_NOTHROW_ASSIGN'
# #     define BOOST_HAS_NOTHROW_ASSIGN(T) (__has_nothrow_assign(T) && !is_volatile<T>::value && is_assignable<T&, const T&>::value)
#                                           ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/serialization.hpp:61:1: note: in instantiation of template class 'boost::has_nothrow_assign<unsigned int>' requested here
# BOOST_STRONG_TYPEDEF(unsigned int, version_type)
# ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/serialization/strong_typedef.hpp:42:57: note: expanded from macro 'BOOST_STRONG_TYPEDEF'
#     D& operator=(const D& rhs) BOOST_NOEXCEPT_IF(boost::has_nothrow_assign<T>::value) {t = rhs.t; return *this;} \
#                                                         ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/traits.hpp:27:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits.hpp:66:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_nothrow_destructor.hpp:12:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_trivial_destructor.hpp:30:86: warning: builtin __has_trivial_destructor is deprecated; use __is_trivially_destructible instead [-Wdeprecated-builtins]
# template <typename T> struct has_trivial_destructor : public integral_constant<bool, BOOST_HAS_TRIVIAL_DESTRUCTOR(T)>{};
#                                                                                      ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:196:47: note: expanded from macro 'BOOST_HAS_TRIVIAL_DESTRUCTOR'
# #     define BOOST_HAS_TRIVIAL_DESTRUCTOR(T) (__has_trivial_destructor(T)  && is_destructible<T>::value)
#                                               ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/traits.hpp:27:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits.hpp:75:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_trivial_assign.hpp:29:7: warning: builtin __has_trivial_assign is deprecated; use __is_trivially_assignable instead [-Wdeprecated-builtins]
#       BOOST_HAS_TRIVIAL_ASSIGN(T)
#       ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:193:43: note: expanded from macro 'BOOST_HAS_TRIVIAL_ASSIGN'
# #     define BOOST_HAS_TRIVIAL_ASSIGN(T) (__has_trivial_assign(T) && !is_volatile<T>::value && is_assignable<T&, const T&>::value)
#                                           ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/traits.hpp:27:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits.hpp:76:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_trivial_constructor.hpp:41:69: warning: builtin __has_trivial_constructor is deprecated; use __is_trivially_constructible instead [-Wdeprecated-builtins]
#    : public integral_constant <bool, ((::boost::is_pod<T>::value || BOOST_HAS_TRIVIAL_CONSTRUCTOR(T)) BOOST_TT_TRIVIAL_CONSTRUCT_FIX)>{};
#                                                                     ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:187:47: note: expanded from macro 'BOOST_HAS_TRIVIAL_CONSTRUCTOR'
# #     define BOOST_HAS_TRIVIAL_CONSTRUCTOR(T) __has_trivial_constructor(T)
#                                               ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:25:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/util/ublas_wrapper.hpp:23:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/vector.hpp:21:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/storage.hpp:26:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/ublas/traits.hpp:27:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits.hpp:77:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/has_trivial_copy.hpp:34:4: warning: builtin __has_trivial_copy is deprecated; use __is_trivially_copyable instead [-Wdeprecated-builtins]
#    BOOST_HAS_TRIVIAL_COPY(T) BOOST_TT_TRIVIAL_CONSTRUCT_FIX
#    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/type_traits/intrinsics.hpp:190:41: note: expanded from macro 'BOOST_HAS_TRIVIAL_COPY'
# #     define BOOST_HAS_TRIVIAL_COPY(T) (__has_trivial_copy(T) && !is_reference<T>::value)
#                                         ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:37:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/stepper/dense_output_runge_kutta.hpp:40:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/integrate/max_step_checker.hpp:72:18: warning: 'sprintf' is deprecated: This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead. [-Wdeprecated-declarations]
#             std::sprintf(error_msg, "Max number of iterations exceeded (%d).", m_max_steps);
#                  ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/stdio.h:180:1: note: 'sprintf' has been explicitly marked deprecated here
# __deprecated_msg("This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead.")
# ^
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/sys/cdefs.h:215:48: note: expanded from macro '__deprecated_msg'
#         #define __deprecated_msg(_msg) __attribute__((__deprecated__(_msg)))
#                                                       ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:344:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr.hpp:46:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/arr/functor/integrate_ode_rk45.hpp:17:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint.hpp:37:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/stepper/dense_output_runge_kutta.hpp:40:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/boost_1.69.0/boost/numeric/odeint/integrate/max_step_checker.hpp:104:18: warning: 'sprintf' is deprecated: This function is provided for compatibility reasons only.  Due to security concerns inherent in the design of sprintf(3), it is highly recommended that you use snprintf(3) instead. [-Wdeprecated-declarations]
# ...
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/ArrayBase.h:194:3: note: (skipping 4 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   call_assignment(derived(), other.derived(), internal::add_assign_op<Scalar,typename OtherDerived::Scalar>());
#   ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/variational/advi.hpp:497:17: note: in instantiation of member function 'stan::variational::advi<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, stan::variational::normal_meanfield, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>::adapt_eta' requested here
#           eta = adapt_eta(variational, adapt_iterations, logger);
#                 ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/services/experimental/advi/meanfield.hpp:87:20: note: in instantiation of member function 'stan::variational::advi<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, stan::variational::normal_meanfield, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>::run' requested here
#           cmd_advi.run(eta, adapt_engaged, adapt_iterations,
#                    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan_fit.hpp:1388:15: note: in instantiation of function template specialization 'stan::services::experimental::advi::meanfield<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7>' requested here
#             ::meanfield(model, *init_context_ptr,
#               ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan_fit.hpp:1649:15: note: in instantiation of function template specialization 'pystan::(anonymous namespace)::command<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>' requested here
#         ret = command(args, model_, holder, names_oi_tidx_,
#               ^
# /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:16205:33: note: in instantiation of member function 'pystan::stan_fit<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>::call_sampler' requested here
#     __pyx_t_4 = __pyx_v_fitptr->call_sampler((*__pyx_v_argsptr), (*__pyx_v_holderptr));
#                                 ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:9:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/meta/as_array_or_scalar.hpp:4:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Dense:1:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/Core:420:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:86:63: warning: converting the enum constant to a boolean [-Wint-in-bool-context]
#     MayLinearVectorize = bool(MightVectorize) && MayLinearize && DstHasDirectAccess
#                                                               ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:607:20: note: in instantiation of template class 'Eigen::internal::copy_using_evaluator_traits<Eigen::internal::evaluator<Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>>, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_exp_op<double>, const Eigen::ArrayWrapper<const Eigen::Matrix<double, -1, 1>>>>>, Eigen::internal::assign_op<double, double>>' requested here
#   typedef typename AssignmentTraits::PacketType PacketType;
#                    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:739:10: note: in instantiation of template class 'Eigen::internal::generic_dense_assignment_kernel<Eigen::internal::evaluator<Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>>, Eigen::internal::evaluator<Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_exp_op<double>, const Eigen::ArrayWrapper<const Eigen::Matrix<double, -1, 1>>>>>, Eigen::internal::assign_op<double, double>>' requested here
#   Kernel kernel(dstEvaluator, srcEvaluator, func, dst.const_cast_derived());
#          ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:879:5: note: in instantiation of function template specialization 'Eigen::internal::call_dense_assignment_loop<Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_exp_op<double>, const Eigen::ArrayWrapper<const Eigen::Matrix<double, -1, 1>>>>, Eigen::internal::assign_op<double, double>>' requested here
#     call_dense_assignment_loop(dst, src, func);
#     ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:836:46: note: in instantiation of member function 'Eigen::internal::Assignment<Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_exp_op<double>, const Eigen::ArrayWrapper<const Eigen::Matrix<double, -1, 1>>>>, Eigen::internal::assign_op<double, double>>::run' requested here
#   Assignment<ActualDstTypeCleaned,Src,Func>::run(actualDst, src, func);
#                                              ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:804:3: note: in instantiation of function template specialization 'Eigen::internal::call_assignment_no_alias<Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, Eigen::CwiseBinaryOp<Eigen::internal::scalar_product_op<double>, const Eigen::ArrayWrapper<Eigen::Matrix<double, -1, 1>>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_exp_op<double>, const Eigen::ArrayWrapper<const Eigen::Matrix<double, -1, 1>>>>, Eigen::internal::assign_op<double, double>>' requested here
#   call_assignment_no_alias(dst, src, func);
#   ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/lib/eigen_3.3.3/Eigen/src/Core/AssignEvaluator.h:782:3: note: (skipping 6 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
#   call_assignment(dst, src, internal::assign_op<typename Dst::Scalar,typename Src::Scalar>());
#   ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/variational/advi.hpp:497:17: note: in instantiation of member function 'stan::variational::advi<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, stan::variational::normal_meanfield, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>::adapt_eta' requested here
#           eta = adapt_eta(variational, adapt_iterations, logger);
#                 ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/services/experimental/advi/meanfield.hpp:87:20: note: in instantiation of member function 'stan::variational::advi<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, stan::variational::normal_meanfield, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>::run' requested here
#           cmd_advi.run(eta, adapt_engaged, adapt_iterations,
#                    ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan_fit.hpp:1388:15: note: in instantiation of function template specialization 'stan::services::experimental::advi::meanfield<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7>' requested here
#             ::meanfield(model, *init_context_ptr,
#               ^
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan_fit.hpp:1649:15: note: in instantiation of function template specialization 'pystan::(anonymous namespace)::command<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>' requested here
#         ret = command(args, model_, holder, names_oi_tidx_,
#               ^
# /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:16205:33: note: in instantiation of member function 'pystan::stan_fit<anon_model_cb4cc9c2a04d0e34d711077557307fb7_namespace::anon_model_cb4cc9c2a04d0e34d711077557307fb7, boost::random::additive_combine_engine<boost::random::linear_congruential_engine<unsigned int, 40014, 0, 2147483563>, boost::random::linear_congruential_engine<unsigned int, 40692, 0, 2147483399>>>::call_sampler' requested here
#     __pyx_t_4 = __pyx_v_fitptr->call_sampler((*__pyx_v_argsptr), (*__pyx_v_holderptr));
#                                 ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1286:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:336:
# In file included from /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_log.hpp:5:
# /Users/h6x/anaconda3/envs/DSE/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_lpmf.hpp:64:59: warning: unused typedef 'T_alpha_val' [-Wunused-local-typedef]
#       typename partials_return_type<T_alpha>::type>::type T_alpha_val;
#                                                           ^
# In file included from /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979.cpp:1289:
# /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/pystan_bzvm8hsn/anon_model_cb4cc9c2a04d0e34d711077557307fb7.hpp:125:24: warning: unused typedef 'local_scalar_t__' [-Wunused-local-typedef]
#         typedef double local_scalar_t__;
#                        ^
# 209 warnings generated.
# ld: warning: duplicate -rpath '/Users/h6x/anaconda3/envs/DSE/lib' ignored
# Process SpawnPoolWorker-2:
# Traceback (most recent call last):
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979'
# Process SpawnPoolWorker-4:
# Traceback (most recent call last):
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979'
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979'
# Process SpawnPoolWorker-3:
# Traceback (most recent call last):
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/h6x/anaconda3/envs/DSE/lib/python3.9/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_3534442124202904979'

# %%
summary_dict = fit.summary()
df = pd.DataFrame(summary_dict['summary'], 
                  columns=summary_dict['summary_colnames'], 
                  index=summary_dict['summary_rownames'])

alpha_mean, beta_mean = df['mean']['alpha'], df['mean']['beta']

# Extracting traces
alpha = fit['alpha']
beta = fit['beta']
sigma = fit['sigma']
lp = fit['lp__']

# %%
def plot_trace(param, param_name='parameter'):
  """Plot the trace and posterior of a parameter."""
  
  # Summary statistics
  mean = np.mean(param)
  median = np.median(param)
  cred_min, cred_max = np.percentile(param, 2.5), np.percentile(param, 97.5)
  
  # Plotting
  plt.subplot(2,1,1)
  plt.plot(param)
  plt.xlabel('samples')
  plt.ylabel(param_name)
  plt.axhline(mean, color='r', lw=2, linestyle='--')
  plt.axhline(median, color='c', lw=2, linestyle='--')
  plt.axhline(cred_min, linestyle=':', color='k', alpha=0.2)
  plt.axhline(cred_max, linestyle=':', color='k', alpha=0.2)
  plt.title('Trace and Posterior Distribution for {}'.format(param_name))

  plt.subplot(2,1,2)
  plt.hist(param, 30, density=True); sns.kdeplot(param, shade=True)
  plt.xlabel(param_name)
  plt.ylabel('density')
  plt.axvline(mean, color='r', lw=2, linestyle='--',label='mean')
  plt.axvline(median, color='c', lw=2, linestyle='--',label='median')
  plt.axvline(cred_min, linestyle=':', color='k', alpha=0.2, label='95% CI')
  plt.axvline(cred_max, linestyle=':', color='k', alpha=0.2)
  
  plt.gcf().tight_layout()
  plt.legend()
