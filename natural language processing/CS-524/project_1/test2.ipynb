# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# Download NLTK data (run this once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/h6x/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/h6x/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /Users/h6x/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load your text file
with open('/Users/h6x/ORNL/git/learning/natural language processing/CS-524/project_1/data/The_Return_of_Sherlock_Holmes.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# %%
# Normalization: Lowercase and remove special characters
text = text.lower()
text = re.sub(r'[^a-z\s]', '', text)

# %%
text
# Out:
# 'the project gutenberg ebook of the return of sherlock holmes\n    \nthis ebook is for the use of anyone anywhere in the united states and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever you may copy it give it away or reuse it under the terms\nof the project gutenberg license included with this ebook or online\nat wwwgutenbergorg if you are not located in the united states\nyou will have to check the laws of the country where you are located\nbefore using this ebook\n\ntitle the return of sherlock holmes\n\nauthor arthur conan doyle\n\nrelease date march   ebook \n                most recently updated february  \n\nlanguage english\n\ncredits an anonymous volunteer\n\n\n start of the project gutenberg ebook the return of sherlock holmes \n\n\n\n\nthe return of sherlock holmes\n\n\nby sir arthur conan doyle\n\n\ncontents\n\n the adventure of the empty house\n the adventure of the norwood builder\n the adventure of the dancing men\n the adventure 
# ...

# %%
# Tokenization
tokens = word_tokenize(text)

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

# %%
print(lemmatized_tokens[:50])  # Check first 50 tokens
# Out:
# ['project', 'gutenberg', 'ebook', 'return', 'sherlock', 'holmes', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'part', 'world', 'cost', 'almost', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'state', 'check', 'law', 'country', 'located', 'using', 'ebook', 'title', 'return', 'sherlock', 'holmes', 'author', 'arthur', 'conan', 'doyle', 'release', 'date']
